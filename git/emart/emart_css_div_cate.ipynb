# %%
import requests
import scrapy
from scrapy.http import TextResponse
from bs4 import BeautifulSoup as bs
import json
import pandas as pd
import re
import time

# %%
# 소분류 카테고리 url
url_s = "http://emart.ssg.com/disp/category.ssg?dispCtgId={}&page={}".format(sub_category, p)

# %%
# 냉동상품
nd = ["6000097651","6000097652","6000097653","6000097640","6000097639","6000097702","6000097703","6000097704","6000097705","6000097706","6000097707"]

# 냉장식품
nj = ["6000097656","6000097658","6000097669","6000097671","6000097670"]

# 식용유/설탕/소금
oil = ['6000095598',"6000095711","6000095727","6000095709"]

# 장류/조미료
msg = ["6000095605","6000095607","6000095608","6000095604","6000095724","6000095606","6000095712","6000095726","6000095728","6000095729","6000095713","6000095714","6000095715"]

# 소스/양념/육수
src = ["6000095591","6000095590","6000095592","6000095594","6000095609","6000095725","6000095612","6000095593"]

# 밀가루/라면/믹스류
pw = ["6000095595","6000097134"]

# 편의식/가공기타
rt = ["6000097196","6000097637","6000097136","6000095508","6000097138","6000097137","6000095862","6000095506","6000096326"]

# 반찬류
kim = ["6000097506", "6000097507"]

# 과일
fr = ["6000095796", "6000095794"]

# 포장용기
pck = ["0006510363","0006510361","0006510364","0006510365","0006510366","0006510546"]

# 가게위생용품
cln = ["0006510362","0006510367"]

# %%
# 냉동식품

categories = nd
datas = []

for sub_category in categories:
    for p in range(1, 140):
        url_s = "http://emart.ssg.com/disp/category.ssg?dispCtgId={}&page={}".format(sub_category, p)
        response = requests.get(url_s)
        dom = BeautifulSoup(response.content, "html.parser")
        elements = dom.select('#ty_thmb_view > ul > li')

        for element in elements:
            t = element.select_one('div.cunit_info > div.cunit_md.notranslate > div > a > em.tx_ko').text
            pr = element.select_one('div.cunit_info > div.cunit_price.notranslate > div > em').text
            min_gram = re.findall('\d+.?\d?k?[g]', t)
            try:
                ppr = element.select_one('div.cunit_info > div.cunit_prw > div').text.replace("(", "").replace(")", "")
            except:
                ppr = "none"

            if t != "":
                datas.append({"category":sub_category, "title":t, "price":pr, "min_gram":min_gram, "price/gram":ppr})

            else:
                continue
                    
df = pd.DataFrame(datas)
df.tail()
# Out:
#        category                          title   price min_gram price/gram
# 406  6000097651                   건국수제햄세트 모음전★  43,500       []       none
# 407  6000097651          (롯데햄)로스팜 4호 선물세트(1세트)  63,000       []       none
# 408  6000097651  (롯데햄)의성마늘 로스팜 특선 1호 선물세트(1세트)  65,000       []       none
# 409  6000097651   (롯데햄)로스팜 한돈한우 프리미엄 선물세트(1세트)  75,000       []       none
# 410  6000097651              2020 한가위 수제햄 선물세트  88,500       []       none

# %%
len(df)
# Out:
# 1040

# %%
# 냉장식품

categories = nj
datas = []

for sub_category in categories:
    for p in range(1, 140):
        url_s = "http://emart.ssg.com/disp/category.ssg?dispCtgId={}&page={}".format(sub_category, p)
        response = requests.get(url_s)
        dom = BeautifulSoup(response.content, "html.parser")
        elements = dom.select('#ty_thmb_view > ul > li')

        for element in elements:
            t = element.select_one('div.cunit_info > div.cunit_md.notranslate > div > a > em.tx_ko').text
            pr = element.select_one('div.cunit_info > div.cunit_price.notranslate > div > em').text
            min_gram = re.findall('\d+.?\d?k?[g]', t)
            try:
                ppr = element.select_one('div.cunit_info > div.cunit_prw > div').text.replace("(", "").replace(")", "")
            except:
                ppr = "none"

            if t != "":
                datas.append({"category":sub_category, "title":t, "price":pr, "min_gram":min_gram, "price/gram":ppr})

            else:
                break
                    
df_2 = pd.DataFrame(datas)
df_2.tail()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# 식용유 등

categories = oil
datas = []

for sub_category in categories:
    for p in range(1, 140):
        url_s = "http://emart.ssg.com/disp/category.ssg?dispCtgId={}&page={}".format(sub_category, p)
        response = requests.get(url_s)
        dom = BeautifulSoup(response.content, "html.parser")
        elements = dom.select('#ty_thmb_view > ul > li')

        for element in elements:
            t = element.select_one('div.cunit_info > div.cunit_md.notranslate > div > a > em.tx_ko').text
            pr = element.select_one('div.cunit_info > div.cunit_price.notranslate > div > em').text
            min_gram = re.findall('\d+.?\d?k?[g]', t)
            try:
                ppr = element.select_one('div.cunit_info > div.cunit_prw > div').text.replace("(", "").replace(")", "")
            except:
                ppr = "none"

            datas.append({"category":sub_category, "title":t, "price":pr, "min_gram":min_gram, "price/gram":ppr})
                    
df_3 = pd.DataFrame(datas)
df_3.tail()
# Out:
#         category                                   title    price min_gram  \
# 3335  6000095727                (사조해표) 오곡 올리고당 700g x20개   59,300   [700g]
# 3336  6000095727  진 조청선물세트 4종  / 쇼핑백 / 국내산 도라지 생강 인진쑥 3종   60,000       []
# 3337  6000095727                     (청정원) 쌀엿1.2KG x12개.   63,600       []
# 3338  6000095727                     (CJ)쌀올리고당1.2kg x12.   72,300  [1.2kg]
# 3339  6000095727             프리미엄 도자기 선물세트(도라지 조청 1.2kg)  139,000  [1.2kg]
#
#          price/gram
# 3335           none
# 3336           none
# 3337           none
# 3338           none
# 3339  100g당:11,584원

# %%
# 조미료

categories = msg
datas = []

for sub_category in categories:
    for p in range(1, 140):
        url_s = "http://emart.ssg.com/disp/category.ssg?dispCtgId={}&page={}".format(sub_category, p)
        response = requests.get(url_s)
        dom = BeautifulSoup(response.content, "html.parser")
        elements = dom.select('#ty_thmb_view > ul > li')

        for element in elements:
            t = element.select_one('div.cunit_info > div.cunit_md.notranslate > div > a > em.tx_ko').text
            pr = element.select_one('div.cunit_info > div.cunit_price.notranslate > div > em').text
            min_gram = re.findall('\d+.?\d?k?[g]', t)
            try:
                ppr = element.select_one('div.cunit_info > div.cunit_prw > div').text.replace("(", "").replace(")", "")
            except:
                ppr = "none"

            if t != "":
                datas.append({"category":sub_category, "title":t, "price":pr, "min_gram":min_gram, "price/gram":ppr})

            else:
                break
                    
df_4 = pd.DataFrame(datas)
df_4.tail()
# Out:
#        category                         title   price min_gram    price/gram
# 795  6000095605  (사조해표) 순창궁 태양초골드 고추장 2kg x6개  59,300    [2kg]          none
# 796  6000095605       (CJ) 알찬고추장6.5kg(P) x2개.  59,400  [6.5kg]          none
# 797  6000095605      이츠웰 실속 태양초고추장 17kg 고추장초장  59,630   [17kg]          none
# 798  6000095605       자연송이 능이고추장 (유리병) 400gX2  59,900   [400g]  100g당:7,488원
# 799  6000095605   (무) 순창궁햅쌀 초고추장530gx20개(box)  60,220   [530g]          none

# %%
# 소스

categories = src
datas = []

for sub_category in categories:
    for p in range(1, 140):
        url_s = "http://emart.ssg.com/disp/category.ssg?dispCtgId={}&page={}".format(sub_category, p)
        response = requests.get(url_s)
        dom = BeautifulSoup(response.content, "html.parser")
        elements = dom.select('#ty_thmb_view > ul > li')

        for element in elements:
            t = element.select_one('div.cunit_info > div.cunit_md.notranslate > div > a > em.tx_ko').text
            pr = element.select_one('div.cunit_info > div.cunit_price.notranslate > div > em').text
            min_gram = re.findall('\d+.?\d?k?[g]', t)
            try:
                ppr = element.select_one('div.cunit_info > div.cunit_prw > div').text.replace("(", "").replace(")", "")
            except:
                ppr = "none"

            if t != "":
                datas.append({"category":sub_category, "title":t, "price":pr, "min_gram":min_gram, "price/gram":ppr})

            else:
                break
                    
df_5 = pd.DataFrame(datas)
df_5.tail()
# Out:
#        category                           title   price min_gram price/gram
# 315  6000095609  대리야끼 소스 대상 3.5kg 식당용 데리야끼 테리야끼  20,060  [3.5kg]       none
# 316  6000095609   훈제향 소스 스모크향소스 불맛 이슬나라 530g 1개  20,310   [530g]       none
# 317  6000095609             소문난 회모듬양념장 120g 35개  20,630   [120g]       none
# 318  6000095609       대상 데미그라스소스 데미구라소스 가루 720g  20,740   [720g]       none
# 319  6000095609      태원 허니갈릭소스 2Kg 갈릭맛소스 대용량식자재  21,310    [2Kg]       none

# %%
# 밀가루 등

categories = pw
datas = []

for sub_category in categories:
    for p in range(1, 140):
        url_s = "http://emart.ssg.com/disp/category.ssg?dispCtgId={}&page={}".format(sub_category, p)
        response = requests.get(url_s)
        dom = BeautifulSoup(response.content, "html.parser")
        elements = dom.select('#ty_thmb_view > ul > li')

        for element in elements:
            t = element.select_one('div.cunit_info > div.cunit_md.notranslate > div > a > em.tx_ko').text
            pr = element.select_one('div.cunit_info > div.cunit_price.notranslate > div > em').text
            min_gram = re.findall('\d+.?\d?k?[g]', t)
            try:
                ppr = element.select_one('div.cunit_info > div.cunit_prw > div').text.replace("(", "").replace(")", "")
            except:
                ppr = "none"

            if t != "":
                datas.append({"category":sub_category, "title":t, "price":pr, "min_gram":min_gram, "price/gram":ppr})

            else:
                break
                    
df_6 = pd.DataFrame(datas)
df_6.tail()
# Out:
#        category                              title    price min_gram  \
# 467  6000095595               (청은) 알후추 150g x100개.  320,500   [150g]
# 468  6000095595            혼합 생강가루 식자재 400gX20개 솔표  321,040   [400g]
# 469  6000095595     혼합생강가루 생강분 한식재료 승진식품 60gX200EA  324,470    [60g]
# 470  6000095595  생쑥 분말 가루 애담향 100g x15개 차 선식 쑥밥 첨가  349,340   [100g]
# 471  6000095595      넛맥 분말 허브 너트맥 500g X12개 향신료 가루  381,850   [500g]
#
#     price/gram
# 467       none
# 468       none
# 469       none
# 470       none
# 471       none

# %%
# 간편식

categories = rt
datas = []

for sub_category in categories:
    for p in range(1, 140):
        url_s = "http://emart.ssg.com/disp/category.ssg?dispCtgId={}&page={}".format(sub_category, p)
        response = requests.get(url_s)
        dom = BeautifulSoup(response.content, "html.parser")
        elements = dom.select('#ty_thmb_view > ul > li')

        for element in elements:
            t = element.select_one('div.cunit_info > div.cunit_md.notranslate > div > a > em.tx_ko').text
            pr = element.select_one('div.cunit_info > div.cunit_price.notranslate > div > em').text
            min_gram = re.findall('\d+.?\d?k?[g]', t)
            try:
                ppr = element.select_one('div.cunit_info > div.cunit_prw > div').text.replace("(", "").replace(")", "")
            except:
                ppr = "none"

            if t != "":
                datas.append({"category":sub_category, "title":t, "price":pr, "min_gram":min_gram, "price/gram":ppr})

            else:
                break
                    
df_7 = pd.DataFrame(datas)
df_7.tail()
# Out:
#        category                                       title   price min_gram  \
# 795  6000097637         ★SSG특가★ 크루통 모닝수프 트리플치즈 스프 (25gx7개입)  14,000    [25g]
# 796  6000097637  [무료배송][오뚜기] 맛있는 오뚜기 컵밥 차돌 강된장보리밥 315g x 3개  10,500   [315g]
# 797  6000097637                              햄야채 볶음밥 300g_E   2,400   [300g]
# 798  6000097637                             하누소 정통육개장(700g)   6,500   [700g]
# 799  6000097637                이종임의 웅추녹두삼계탕 2팩(팩당1kg), 실온보관  17,900    [1kg]
#
#        price/gram
# 795          none
# 796  100g당:1,112원
# 797   300ea당:800원
# 798          none
# 799          none

# %%
# 김치

categories = kim
datas = []

for sub_category in categories:
    for p in range(1, 140):
        url_s = "http://emart.ssg.com/disp/category.ssg?dispCtgId={}&page={}".format(sub_category, p)
        response = requests.get(url_s)
        dom = BeautifulSoup(response.content, "html.parser")
        elements = dom.select('#ty_thmb_view > ul > li')

        for element in elements:
            t = element.select_one('div.cunit_info > div.cunit_md.notranslate > div > a > em.tx_ko').text
            pr = element.select_one('div.cunit_info > div.cunit_price.notranslate > div > em').text
            min_gram = re.findall('\d+.?\d?k?[g]', t)
            try:
                ppr = element.select_one('div.cunit_info > div.cunit_prw > div').text.replace("(", "").replace(")", "")
            except:
                ppr = "none"

            if t != "":
                datas.append({"category":sub_category, "title":t, "price":pr, "min_gram":min_gram, "price/gram":ppr})

            else:
                break
                    
df_8 = pd.DataFrame(datas)
df_8.tail()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# 과일

categories = fr
datas = []

for sub_category in categories:
    for p in range(1, 140):
        url_s = "http://emart.ssg.com/disp/category.ssg?dispCtgId={}&page={}".format(sub_category, p)
        response = requests.get(url_s)
        dom = BeautifulSoup(response.content, "html.parser")
        elements = dom.select('#ty_thmb_view > ul > li')

        for element in elements:
            t = element.select_one('div.cunit_info > div.cunit_md.notranslate > div > a > em.tx_ko').text
            pr = element.select_one('div.cunit_info > div.cunit_price.notranslate > div > em').text
            min_gram = re.findall('\d+.?\d?k?[g]', t)
            try:
                ppr = element.select_one('div.cunit_info > div.cunit_prw > div').text.replace("(", "").replace(")", "")
            except:
                ppr = "none"

            if t != "":
                datas.append({"category":sub_category, "title":t, "price":pr, "min_gram":min_gram, "price/gram":ppr})

            else:
                break
                    
df_9 = pd.DataFrame(datas)
df_9.tail()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# 포장용기

categories = pck
datas = []

for sub_category in categories:
    for p in range(1, 140):
        url_s = "http://emart.ssg.com/disp/category.ssg?dispCtgId={}&page={}".format(sub_category, p)
        response = requests.get(url_s)
        dom = BeautifulSoup(response.content, "html.parser")
        elements = dom.select('#ty_thmb_view > ul > li')

        for element in elements:
            t = element.select_one('div.cunit_info > div.cunit_md.notranslate > div > a > em.tx_ko').text
            pr = element.select_one('div.cunit_info > div.cunit_price.notranslate > div > em').text
            min_gram = re.findall('\d+.?\d?k?[g]', t)
            try:
                ppr = element.select_one('div.cunit_info > div.cunit_prw > div').text.replace("(", "").replace(")", "")
            except:
                ppr = "none"

            if t != "":
                datas.append({"category":sub_category, "title":t, "price":pr, "min_gram":min_gram, "price/gram":ppr})

            else:
                break
                    
df_10 = pd.DataFrame(datas)
df_10.tail()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# 주방위생용품

categories = cln
datas = []

for sub_category in categories:
    for p in range(1, 140):
        url_s = "http://emart.ssg.com/disp/category.ssg?dispCtgId={}&page={}".format(sub_category, p)
        response = requests.get(url_s)
        dom = BeautifulSoup(response.content, "html.parser")
        elements = dom.select('#ty_thmb_view > ul > li')

        for element in elements:
            t = element.select_one('div.cunit_info > div.cunit_md.notranslate > div > a > em.tx_ko').text
            pr = element.select_one('div.cunit_info > div.cunit_price.notranslate > div > em').text
            min_gram = re.findall('\d+.?\d?k?[g]', t)
            try:
                ppr = element.select_one('div.cunit_info > div.cunit_prw > div').text.replace("(", "").replace(")", "")
            except:
                ppr = "none"

            if t != "":
                datas.append({"category":sub_category, "title":t, "price":pr, "min_gram":min_gram, "price/gram":ppr})

            else:
                break
                    
df_11 = pd.DataFrame(datas)
df_11.tail()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# 유제품
yjp = "6000095501"

# 야채/채소
vg = "6000095740"

# 쌀/잡곡/견과
rc = "6000095498"

# 수산/건어물
fs = "6000095500"

# 축산/계란
mt = "6000095499"

# %%
# 식품류 대분류 카테고리 url
url_b = "http://emart.ssg.com/disp/category.ssg?ctgId={}&page={}".format(cate, p)

# %%
cate = yjp
datas_b = []


for p in range(1, 140):
    url_b = "http://emart.ssg.com/disp/category.ssg?ctgId={}&page={}".format(cate, p)
    response = requests.get(url_b)
    dom = BeautifulSoup(response.content, "html.parser")
    elements = dom.select('#ty_thmb_view > ul > li')

    for element in elements:
        t = element.select_one('div.cunit_info > div.cunit_md.notranslate > div > a > em.tx_ko').text
        pr = element.select_one('div.cunit_info > div.cunit_price.notranslate > div > em').text
        min_gram = re.findall('\d+.?\d?k?[g]', t)
        try:
            ppr = element.select_one('div.cunit_info > div.cunit_prw > div').text.replace("(", "").replace(")", "")
        except:
            ppr = "none"

        datas_b.append({"category":cate, "title":t, "price":pr, "min_gram":min_gram, "price/gram":ppr})     

            
df_12 = pd.DataFrame(datas_b)
df_12.tail()
# Out:
#        category                              title   price min_gram  \
# 795  6000095501                쁘띠구르망 쌀과자 스틱 과일 20g   2,980    [20g]
# 796  6000095501  [매일] 아몬드브리즈 오리지널 190ml*24입 (NEO2)  13,900       []
# 797  6000095501                      쌀과자 스틱 채소 20g   2,980    [20g]
# 798  6000095501               [프레지덩] 브리 쁘띠 치즈 125g   5,400   [125g]
# 799  6000095501         매일유업 소화가 잘되는우유 홍삼 190ml*6팩   5,380       []
#
#        price/gram
# 795   10g당:1,490원
# 796   100ml당:305원
# 797   10g당:1,490원
# 798  100g당:4,320원
# 799   100ml당:472원

# %%
cate = vg
datas_b = []


for p in range(1, 140):
    url_b = "http://emart.ssg.com/disp/category.ssg?ctgId={}&page={}".format(cate, p)
    response = requests.get(url_b)
    dom = BeautifulSoup(response.content, "html.parser")
    elements = dom.select('#ty_thmb_view > ul > li')

    for element in elements:
        t = element.select_one('div.cunit_info > div.cunit_md.notranslate > div > a > em.tx_ko').text
        pr = element.select_one('div.cunit_info > div.cunit_price.notranslate > div > em').text
        min_gram = re.findall('\d+.?\d?k?[g]', t)
        try:
            ppr = element.select_one('div.cunit_info > div.cunit_prw > div').text.replace("(", "").replace(")", "")
        except:
            ppr = "none"
        datas_b.append({"category":cate, "title":t, "price":pr, "min_gram":min_gram, "price/gram":ppr})     
df_13 = pd.DataFrame(datas_b)
df_13.tail()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
cate = rc
datas_b = []


for p in range(1, 140):
    url_b = "http://emart.ssg.com/disp/category.ssg?ctgId={}&page={}".format(cate, p)
    response = requests.get(url_b)
    dom = BeautifulSoup(response.content, "html.parser")
    elements = dom.select('#ty_thmb_view > ul > li')

    for element in elements:
        t = element.select_one('div.cunit_info > div.cunit_md.notranslate > div > a > em.tx_ko').text
        pr = element.select_one('div.cunit_info > div.cunit_price.notranslate > div > em').text
        min_gram = re.findall('\d+.?\d?k?[g]', t)
        try:
            ppr = element.select_one('div.cunit_info > div.cunit_prw > div').text.replace("(", "").replace(")", "")
        except:
            ppr = "none"
        datas_b.append({"category":cate, "title":t, "price":pr, "min_gram":min_gram, "price/gram":ppr})     
df_14 = pd.DataFrame(datas_b)
df_14.tail()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
cate = fs
datas_b = []


for p in range(1, 140):
    url_b = "http://emart.ssg.com/disp/category.ssg?ctgId={}&page={}".format(cate, p)
    response = requests.get(url_b)
    dom = BeautifulSoup(response.content, "html.parser")
    elements = dom.select('#ty_thmb_view > ul > li')

    for element in elements:
        t = element.select_one('div.cunit_info > div.cunit_md.notranslate > div > a > em.tx_ko').text
        pr = element.select_one('div.cunit_info > div.cunit_price.notranslate > div > em').text
        min_gram = re.findall('\d+.?\d?k?[g]', t)
        try:
            ppr = element.select_one('div.cunit_info > div.cunit_prw > div').text.replace("(", "").replace(")", "")
        except:
            ppr = "none"
        datas_b.append({"category":cate, "title":t, "price":pr, "min_gram":min_gram, "price/gram":ppr})     
df_15 = pd.DataFrame(datas_b)
df_15.tail()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
cate = mt
datas_b = []


for p in range(1, 140):
    url_b = "http://emart.ssg.com/disp/category.ssg?ctgId={}&page={}".format(cate, p)
    response = requests.get(url_b)
    dom = BeautifulSoup(response.content, "html.parser")
    elements = dom.select('#ty_thmb_view > ul > li')

    for element in elements:
        t = element.select_one('div.cunit_info > div.cunit_md.notranslate > div > a > em.tx_ko').text
        pr = element.select_one('div.cunit_info > div.cunit_price.notranslate > div > em').text
        min_gram = re.findall('\d+.?\d?k?[g]', t)
        try:
            ppr = element.select_one('div.cunit_info > div.cunit_prw > div').text.replace("(", "").replace(")", "")
        except:
            ppr = "none"
        datas_b.append({"category":cate, "title":t, "price":pr, "min_gram":min_gram, "price/gram":ppr})     
df_16 = pd.DataFrame(datas_b)
df_16.tail()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
dfs = pd.concat([df, df_2, df_3, df_4, df_5, df_6, df_7, df_8, df_9, df_10, df_11, df_12, df_13, df_14, df_15, df_16]).reset_index(drop=True)
dfs
# Out:
#         category                                      title   price  \
# 0     6000097702                            동원 양반김만두 385gx2   8,480
# 1     6000097702          [CJ직배송] 비비고 곤드레나물밥 433g X3개(총6인분)  20,940
# 2     6000097702                    [남대문가메골] 고기 호빵 왕만두 850g   8,000
# 3     6000097702  [CJ직배송]비비고 왕교자455g X4개+ 청양고추찐만두 162g X 2개  20,600
# 4     6000097702                   [대림]선 왕교자 910g(455g*2개입)   7,480
# ...          ...                                        ...     ...
# 5027  6000095501                        쁘띠구르망 쌀과자 스틱 과일 20g   2,980
# 5028  6000095501          [매일] 아몬드브리즈 오리지널 190ml*24입 (NEO2)  13,900
# 5029  6000095501                              쌀과자 스틱 채소 20g   2,980
# 5030  6000095501                       [프레지덩] 브리 쁘띠 치즈 125g   5,400
# 5031  6000095501                 매일유업 소화가 잘되는우유 홍삼 190ml*6팩   5,380
#
#           min_gram    price/gram
# 0           [385g]  100g당:1,102원
# 1           [433g]          none
# 2           [850g]          none
# 3     [455g, 162g]          none
# 4     [910g, 455g]    100g당:822원
# ...            ...           ...
# 5027         [20g]   10g당:1,490원
# 5028            []   100ml당:305원
# 5029         [20g]   10g당:1,490원
# 5030        [125g]  100g당:4,320원
# 5031            []   100ml당:472원
#
# [5032 rows x 5 columns]
